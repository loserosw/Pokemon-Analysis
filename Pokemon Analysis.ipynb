# %%
import pandas as pd
pokemon = pd.read_csv("Pokemon.csv")
pokemon
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
import seaborn as sns
ax = sns.countplot(data=pokemon, x="Generation", hue="Generation", palette="bright")
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
for i in ax.containers:
    ax.bar_label(i,)

# %%
total_pokemon = pokemon.nlargest(20, "Total")
total_pokemon
# Out:
#        #                     Name   Type 1    Type 2  Total   HP  Attack  \
# 163  150      MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190
# 164  150      MewtwoMega Mewtwo Y  Psychic       NaN    780  106     150
# 426  384    RayquazaMega Rayquaza   Dragon    Flying    780  105     180
# 422  382      KyogrePrimal Kyogre    Water       NaN    770  100     150
# 424  383    GroudonPrimal Groudon   Ground      Fire    770  100     180
# 552  493                   Arceus   Normal       NaN    720  120     120
# 268  248  TyranitarMega Tyranitar     Rock      Dark    700  100     164
# 409  373  SalamenceMega Salamence   Dragon    Flying    700   95     145
# 413  376  MetagrossMega Metagross    Steel   Psychic    700   80     145
# 418  380        LatiasMega Latias   Dragon   Psychic    700   80     100
# 420  381        LatiosMega Latios   Dragon   Psychic    700   80     130
# 494  445    GarchompMega Garchomp   Dragon    Ground    700  108     170
# ...

# %%
ato = sns.barplot(data=total_pokemon, x="Total", y="Name", hue="Generation", palette="bright")
sns.move_legend(ato, "upper left", bbox_to_anchor=(1, 1))
for i in ato.containers:
    ato.bar_label(i,)

# %%
total_pokemon = pokemon.nlargest(20, "Total")
total_pokemon
ato = sns.barplot(data=total_pokemon, x="Total", y="Name", hue="Legendary", palette="bright")
sns.move_legend(ato, "upper left", bbox_to_anchor=(1, 1))
for i in ato.containers:
    ato.bar_label(i,)

# %%
hp_pokemon = pokemon.nlargest(10, "HP")
ac = sns.barplot(data=hp_pokemon, x="HP", y="Name", hue="Type 1", palette="bright")

for i in ac.containers:
    ac.bar_label(i,)

# %%
attack_pok = pokemon.nlargest(10, "Attack")
at = sns.barplot(data=attack_pok, x="Attack", y="Name", hue="Type 1", palette='bright')
sns.move_legend(at, "upper left", bbox_to_anchor=(1, 1))
for i in at.containers:
    at.bar_label(i,)

# %%
defense_pok = pokemon.nlargest(10, "Defense")
defense_pok
ad = sns.barplot(data=defense_pok, x="Defense", y="Name", hue="Type 1", palette='bright')
sns.move_legend(ad, "upper left", bbox_to_anchor=(1, 1))
for i in ad.containers:
    ad.bar_label(i,)

# %%
special_atk_pok = pokemon.nlargest(10, "Sp. Atk")
spa = sns.barplot(data=special_atk_pok, x="Sp. Atk", y="Name", hue="Type 1", palette='bright')
sns.move_legend(spa, "upper left", bbox_to_anchor=(1, 1))
for i in spa.containers:
    spa.bar_label(i,)

# %%
sp_def_pok = pokemon.nlargest(10, "Sp. Def")
sp_d= sns.barplot(data=sp_def_pok, x="Sp. Def", y="Name",hue="Type 1", palette='bright')
sns.move_legend(sp_d, "upper left", bbox_to_anchor=(1, 1))
for i in sp_d.containers:
    sp_d.bar_label(i,)

# %%
speed_pok = pokemon.nlargest(10, "Speed")
spd_pok = sns.barplot(data=speed_pok,x="Speed",y="Name",hue="Type 1", palette="bright")
sns.move_legend(spd_pok, "upper left", bbox_to_anchor=(1, 1))
for i in spd_pok.containers:
    spd_pok.bar_label(i,)
